# %%
import pandas as pd
import datetime as dt
import pandas_datareader as pd_dr

# %%
company = ['IBM', 'AAPL', 'FB', 'GOOGL']
tickers = ['AAPL','MSFT','GE','IBM','AA','DAL','UAL', 'PEP', 'KO']

stock_exchange = pd_dr.data.get_data_yahoo(company, start='2013-01-01', end='2019-03-14')
stock_exchange
# Out:
# Attributes        High                                              Low  \
# Symbols           AAPL          FB        GOOGL         IBM        AAPL
# Date
# 2013-01-02   79.285713   28.180000   363.863861  196.350006   77.375717
# 2013-01-03   78.524284   28.469999   366.331329  196.289993   77.285713
# 2013-01-04   76.947144   28.930000   371.106110  194.460007   75.118568
# 2013-01-07   75.614288   29.790001   370.060059  193.779999   73.599998
# 2013-01-08   75.984283   29.600000   368.518524  193.300003   74.464287
# 2013-01-09   75.001427   30.600000   369.544556  193.490005   73.712860
# 2013-01-10   75.531425   31.450001   372.872864  192.960007   73.645714
# 2013-01-11   75.045715   31.959999   371.586578  195.000000   74.145714
# 2013-01-14   72.500000   32.209999   371.471466  193.279999   71.215714
# 2013-01-15   71.284286   31.709999   367.867859  192.729996   69.054283
# 2013-01-16   72.777145   30.350000   362.532532  193.179993   70.357140
# ...

# %%
stock_exchange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1560 entries, 2013-01-02 to 2019-03-14
# Data columns (total 24 columns):
# (High, AAPL)          1560 non-null float64
# (High, FB)            1560 non-null float64
# (High, GOOGL)         1560 non-null float64
# (High, IBM)           1560 non-null float64
# (Low, AAPL)           1560 non-null float64
# (Low, FB)             1560 non-null float64
# (Low, GOOGL)          1560 non-null float64
# (Low, IBM)            1560 non-null float64
# (Open, AAPL)          1560 non-null float64
# (Open, FB)            1560 non-null float64
# (Open, GOOGL)         1560 non-null float64
# (Open, IBM)           1560 non-null float64
# (Close, AAPL)         1560 non-null float64
# (Close, FB)           1560 non-null float64
# (Close, GOOGL)        1560 non-null float64
# (Close, IBM)          1560 non-null float64
# (Volume, AAPL)        1560 non-null float64
# (Volume, FB)          1560 non-null float64
# ...

# %%
stock_exchange.Volume.AAPL.plot();
